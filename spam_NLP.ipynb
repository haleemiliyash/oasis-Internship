# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from nltk.corpus import stopwords
from sklearn.pipeline import Pipeline    
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import precision_score, recall_score, classification_report, accuracy_score, f1_score

# %%
data=pd.read_csv("D:/project/.venv/Internship/spam_mail/spam.csv", encoding='latin-1')
data.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
data['v1'].unique()
# Out:
# array(['ham', 'spam'], dtype=object)

# %%
data.rename(columns={'v1':'target','v2':'Message'},inplace=True)
data.head()
# Out:
#   target                                            Message Unnamed: 2  \
# 0    ham  Go until jurong point, crazy.. Available only ...        NaN
# 1    ham                      Ok lar... Joking wif u oni...        NaN
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3    ham  U dun say so early hor... U c already then say...        NaN
# 4    ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
data_txt = data.drop(columns = ["Unnamed: 2","Unnamed: 3","Unnamed: 4"], axis=1)

# %%
data_txt.head()
# Out:
#   target                                            Message
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# # Lower Case

# %%
data_txt['Message']=data_txt['Message'].str.lower()
data_txt.head()
# Out:
#   target                                            Message
# 0    ham  go until jurong point, crazy.. available only ...
# 1    ham                      ok lar... joking wif u oni...
# 2   spam  free entry in 2 a wkly comp to win fa cup fina...
# 3    ham  u dun say so early hor... u c already then say...
# 4    ham  nah i don't think he goes to usf, he lives aro...

# %%
data_txt.shape
# Out:
# (5572, 2)

# %% [markdown]
# # Data pre processing
# ## Duplicate Data

# %%
data_txt.duplicated().sum()
# Out:
# 404

# %%
data_txt.drop_duplicates(inplace=True)

# %% [markdown]
# # Remove white space

# %%
def remove_whitespace(text):
  return " ".join(text.split())

data_txt['Message']=data_txt['Message'].apply(remove_whitespace)

# %% [markdown]
# # Tokenization

# %%
import nltk
nltk.download('punkt')
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\halee\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
data_txt['Message']=data_txt['Message'].apply(lambda X: word_tokenize(X))
data_txt.head()
# Out:
#   target                                            Message
# 0    ham  [go, until, jurong, point, ,, crazy, .., avail...
# 1    ham           [ok, lar, ..., joking, wif, u, oni, ...]
# 2   spam  [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3    ham  [u, dun, say, so, early, hor, ..., u, c, alrea...
# 4    ham  [nah, i, do, n't, think, he, goes, to, usf, ,,...

# %%
data_txt['Message'][0]
# Out:
# ['go',
#  'until',
#  'jurong',
#  'point',
#  ',',
#  'crazy',
#  '..',
#  'available',
#  'only',
#  'in',
#  'bugis',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet',
#  '...',
#  'cine',
#  'there',
#  'got',
#  'amore',
#  'wat',
#  '...']

# %% [markdown]
# # Remove Stopward

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\halee\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
en_stopwords = stopwords.words('english')
def remove_stopwords(text):
  result = []
  for token in text:
    if token not in en_stopwords:
      result.append(token)
  return result

# %%
data_txt['Message'] = data_txt['Message'].apply(remove_stopwords)
data_txt['Message']
# Out:
# 0       [go, jurong, point, ,, crazy, .., available, b...
# 1                [ok, lar, ..., joking, wif, u, oni, ...]
# 2       [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3       [u, dun, say, early, hor, ..., u, c, already, ...
# 4       [nah, n't, think, goes, usf, ,, lives, around,...
#                               ...
# 5567    [2nd, time, tried, 2, contact, u., u, å£750, p...
# 5568               [ì_, b, going, esplanade, fr, home, ?]
# 5569           [pity, ,, *, mood, ., ..., suggestions, ?]
# 5570    [guy, bitching, acted, like, 'd, interested, b...
# 5571                                [rofl, ., true, name]
# Name: Message, Length: 5168, dtype: object

# %% [markdown]
# # Remove puncution

# %%
from nltk.tokenize import RegexpTokenizer
def remove_punct(text):
  tokenizer = RegexpTokenizer(r"\w+")
  lst=tokenizer.tokenize(' '.join(text))
  return lst

# %%
data_txt['Message'] = data_txt['Message'].apply(remove_punct)
data_txt['Message']
# Out:
# 0       [go, jurong, point, crazy, available, bugis, n...
# 1                          [ok, lar, joking, wif, u, oni]
# 2       [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3           [u, dun, say, early, hor, u, c, already, say]
# 4       [nah, n, t, think, goes, usf, lives, around, t...
#                               ...
# 5567    [2nd, time, tried, 2, contact, u, u, å, 750, p...
# 5568                  [ì_, b, going, esplanade, fr, home]
# 5569                            [pity, mood, suggestions]
# 5570    [guy, bitching, acted, like, d, interested, bu...
# 5571                                   [rofl, true, name]
# Name: Message, Length: 5168, dtype: object

# %%
from nltk import FreqDist


def frequent_words(df):
    lst=[]
    for text in df.values:
        lst+=text[0]
    fdist=FreqDist(lst)
    return fdist.most_common(20)
frequent_words(data_txt)
# Out:
# [('a', 5168), ('m', 5168), ('h', 4515), ('s', 653), ('p', 653)]

# %%
freq_words = frequent_words(data_txt)


lst = []
for a,b in freq_words:
  lst.append(b)


def remove_freq_words(text):
  result=[]
  for item in text:
    if item not in lst:
      result.append(item)
  return result

data_txt['Message']=data_txt['Message'].apply(remove_freq_words)

# %% [markdown]
# # Removal of tags

# %%
import re
def remove_tag(text):


    text=' '.join(text)
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

# %%
data_txt['Message']=data_txt['Message'].apply(remove_tag)
data_txt.head()
# Out:
#   target                                            Message
# 0    ham  go jurong point crazy available bugis n great ...
# 1    ham                            ok lar joking wif u oni
# 2   spam  free entry 2 wkly comp win fa cup final tkts 2...
# 3    ham                u dun say early hor u c already say
# 4    ham         nah n t think goes usf lives around though

# %% [markdown]
# # Removal of tags

# %%
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

# %%
data_txt['Message']=data_txt['Message'].apply(remove_urls)
data_txt.head()
# Out:
#   target                                            Message
# 0    ham  go jurong point crazy available bugis n great ...
# 1    ham                            ok lar joking wif u oni
# 2   spam  free entry 2 wkly comp win fa cup final tkts 2...
# 3    ham                u dun say early hor u c already say
# 4    ham         nah n t think goes usf lives around though

# %% [markdown]
# # chat word removal

# %%
chat_words_str = """
AFAIK=As Far As I Know
AFK=Away From Keyboard
ASAP=As Soon As Possible
ATK=At The Keyboard
ATM=At The Moment
A3=Anytime, Anywhere, Anyplace
BAK=Back At Keyboard
BBL=Be Back Later
BBS=Be Back Soon
BFN=Bye For Now
B4N=Bye For Now
BRB=Be Right Back
BRT=Be Right There
BTW=By The Way
B4=Before
B4N=Bye For Now
CU=See You
CUL8R=See You Later
CYA=See You
FAQ=Frequently Asked Questions
FC=Fingers Crossed
FWIW=For What It's Worth
FYI=For Your Information
GAL=Get A Life
GG=Good Game
GN=Good Night
GMTA=Great Minds Think Alike
GR8=Great!
G9=Genius
IC=I See
ICQ=I Seek you (also a chat program)
ILU=ILU: I Love You
IMHO=In My Honest/Humble Opinion
IMO=In My Opinion
IOW=In Other Words
IRL=In Real Life
KISS=Keep It Simple, Stupid
LDR=Long Distance Relationship
LMAO=Laugh My A.. Off
LMK=Let Me Know
LOL=Laughing Out Loud
LTNS=Long Time No See
L8R=Later
MTE=My Thoughts Exactly
M8=Mate
NRN=No Reply Necessary
OIC=Oh I See
PITA=Pain In The A..
PRT=Party
PRW=Parents Are Watching
ROFL=Rolling On The Floor Laughing
ROFLOL=Rolling On The Floor Laughing Out Loud
ROTFLMAO=Rolling On The Floor Laughing My A.. Off
SK8=Skate
STATS=Your sex and age
ASL=Age, Sex, Location
THX=Thank You
TTFN=Ta-Ta For Now!
TTYL=Talk To You Later
U=You
U2=You Too
U4E=Yours For Ever
WB=Welcome Back
WTF=What The F...
WTG=Way To Go!
WUF=Where Are You From?
W8=Wait...
7K=Sick:-D Laugher
"""

# %%
chat_words_map_dict = {}
chat_words_list = []
for line in chat_words_str.split("\n"):
    if line != "":
        cw = line.split("=")[0]
        cw_expanded = line.split("=")[1]
        chat_words_list.append(cw)
        chat_words_map_dict[cw] = cw_expanded
chat_words_list = set(chat_words_list)

def chat_words_conversion(text):
    new_text = []
    for w in text.split():
        if w.upper() in chat_words_list:
            new_text.append(chat_words_map_dict[w.upper()])
        else:
            new_text.append(w)
    return " ".join(new_text)

# %%
data_txt['Message']=data_txt['Message'].apply(chat_words_conversion)
data_txt.head()
# Out:
#   target                                            Message
# 0    ham  go jurong point crazy available bugis n great ...
# 1    ham                          ok lar joking wif You oni
# 2   spam  free entry 2 wkly comp win fa cup final tkts 2...
# 3    ham            You dun say early hor You c already say
# 4    ham         nah n t think goes usf lives around though

# %% [markdown]
# # Stemming & Lemmatization

# %%
import nltk
nltk.download('omw-1.4')
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\halee\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
def stemming(text):
  porter = PorterStemmer()
  result=[]
  for word in text:
    result.append(porter.stem(word))
  return result

# %%
data_txt['Message']=data_txt['Message'].apply(stemming)
data_txt.head()
# Out:
#   target                                            Message
# 0    ham  [g, o,  , j, u, r, o, n, g,  , p, o, i, n, t, ...
# 1    ham  [o, k,  , l, a, r,  , j, o, k, i, n, g,  , w, ...
# 2   spam  [f, r, e, e,  , e, n, t, r, y,  , 2,  , w, k, ...
# 3    ham  [y, o, u,  , d, u, n,  , s, a, y,  , e, a, r, ...
# 4    ham  [n, a, h,  , n,  , t,  , t, h, i, n, k,  , g, ...

# %%
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize,pos_tag
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\halee\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\halee\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def lemmatization(text):
  result=[]
  wordnet = WordNetLemmatizer()
  for token,tag in pos_tag(text):
    pos=tag[0].lower()
    if pos not in ['a', 'r', 'n', 'v']:
      pos='n'
    result.append(wordnet.lemmatize(token,pos))
  return result

# %%
data_txt['Message']=data_txt['Message'].apply(lemmatization)
data_txt.head()
# Out:
#   target                                            Message
# 0    ham  [g, o,  , j, u, r, o, n, g,  , p, o, i, n, t, ...
# 1    ham  [o, k,  , l, a, r,  , j, o, k, i, n, g,  , w, ...
# 2   spam  [f, r, e, e,  , e, n, t, r, y,  , 2,  , w, k, ...
# 3    ham  [y, o, u,  , d, u, n,  , s, a, y,  , e, a, r, ...
# 4    ham  [n, a, h,  , n,  , t,  , t, h, i, n, k,  , g, ...

# %%
X=data_txt['Message']
data_txt['target']=data_txt['target'].map({'ham':1,'spam':0})
Y=data_txt['target']

# %% [markdown]
# # Model training

# %%
# Splitting data into training and testing
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train_text = [''.join(map(str, vec)) for vec in X_train]
X_test_text = [''.join(map(str, vec)) for vec in X_test]

# %%
X_train_text
# Out:
# ['aight time want come',
#  'mostly like',
#  'free video camera phones half price line rental 12 mths 500 cross ntwk mins 100 txts call mobileupd8 08001950382 call2optout 674',
#  'argh 3g spotty anyway thing remember research province sterling problem free places looked',
#  'per request maangalyam alaipayuthe set callertune callers press 9 copy friends callertune',
#  'please n t text anymore nothing else say',
#  'know shall speak lt gt minutes',
#  'urgent mobile awarded å 2 000 bonus caller prize 1 08 03 2nd attempt contact call 0871 4719 523 box95qu bt national rate',
#  'wif family booking tour package',
#  'reach ten morning',
#  'reading gud habit nan bari hudgi yorge pataistha ertini kano',
#  'sometimes heart remembrs someone much forgets someone soon bcoz heart like everyone liked ones remembered everytime bslvyl',
#  'cant keep talking people sure pay agree price pls tell want really buy much willing pay',
#  'guys',
#  'cocksuckers makes feel better ipads worthless garbage novelty items feel bad even wanting one',
#  'wot wed nite 3 til 9',
#  'haha awesome omw back',
#  'leave you always ignorant',
#  'england v macedonia dont miss goals team news txt ur national team 87077 eg england 87077 try wales scotland 4txt ì¼1 20 poboxox36504w45wq 16',
#  'well s big surprise',
#  'missed call cause yelling scrappy miss you ca n t wait you come home m lonely today',
#  'os called ubandu run without installing hard disk use os copy important files system give repair shop',
#  'dont want hear philosophy say happen',
#  'sian aft meeting supervisor got work 2 liao you working',
#  'ìï neva tell noe m home da aft wat',
#  'need ke qi ìï bored izzit suddenly thk',
#  'small problem auction punj asking tiwary',
#  'greetings consider excused',
#  'broke list reasons nobody s town ca n t tell s sarcastic faggy',
#  'ha you jus ate honey ar sweet',
#  'mmm thats better got roast iåõd b better drinks 2 good indian',
#  'come ur home',
#  'think disturbing da',
#  'hi wo n t b ard 4 christmas enjoy n merry x mas',
#  'hey thk juz go accordin wat discussed yest lor except kb sun cos s nt much lesson go attend kb sat',
#  'nope c ì_',
#  'drug able eat',
#  'old orchard near univ',
#  'captain vijaykanth comedy captain tv drunken',
#  'sign maturity start saying big things actually start understanding small things nice evening bslvyl',
#  'lara said loan lt gt',
#  'n t cancer moms making big deal regular checkup aka pap smear',
#  'laughing out loud happens vegas stays vegas',
#  'yep pretty sculpture',
#  'anytime lor',
#  'wil lt gt minutes got space',
#  'lt gt mins stop somewhere first',
#  'cancel cheyyamo get money back',
#  'easy ah sen got selected means good',
#  'm vivek got call number',
#  'hi m sorry missed call pls call back',
#  'laugh my a.. off take pic send',
#  'remember day',
#  'hi kate evening hope see tomorrow bit bloody babyjontet txt back you xxx',
#  'thts wat wright brother fly',
#  'hey tell blake s address carlos wanted meet got lost s answering phone',
#  'neshanth tel r you',
#  'you get pic msgs phone',
#  'went ur hon lab one',
#  'i ll give plus said grinule greet whenever speak',
#  'house maid murderer coz man murdered lt gt th january public holiday govt instituitions closed including post office understand',
#  '80488 500 free text messages valid 31 december 2005',
#  'forgot takes 3 years shower sorry at your phone dead yet',
#  'ìï wait 4 sch finish ard 5',
#  'stop old man get build snowman snow angels snowball fights',
#  'yun buying school got offer 2000 plus',
#  'k text re way',
#  'n t left yet probably gon na til dinner',
#  'hurting n meaningful lines ever i compromised everything love',
#  'win winner mr t foley ipod exciting prizes soon keep eye ur mobile visit www win 82050 co uk',
#  'long since screamed princess',
#  'm awake oh s',
#  'happy come noon',
#  'mm way railway',
#  '1 20 call cost guess isnt bad miss ya need ya want ya love ya',
#  'latest news police station toilet stolen cops nothing go',
#  'sending greetings joy happiness great! evening',
#  'hello thanx taking call got job starts monday',
#  're done',
#  'olol printed forum post guy exact prob fixed gpu replacement hopefully dont ignore',
#  'hi probably much fun get message thought id txt you cos im bored james farting night',
#  'dude got haircut breezy',
#  'going thru different feeling wavering decisions coping individual time heal everything believe',
#  'yes ammae life takes lot turns sit try hold steering',
#  'oh gei happend tron maybe ill dl 3d',
#  'refused loan secured unsecured ca n t get credit call free 0800 195 6669 text back help',
#  'management puzzeles',
#  'call germany 1 pence per minute call fixed line via access number 0844 861 85 85 prepayment direct access www telediscount co uk',
#  'may call later pls',
#  'dont file bag work called me i ll tell find anything room',
#  'two cartons you pleased shelves',
#  'hope ve settled new school year wishin great! day',
#  'jane babes goin 2 wrk feel ill lst nite foned already cover 4 chuck',
#  'saturday sunday holiday difficult',
#  'm going 2 orchard laready reaching soon you reaching',
#  'eatin lunch',
#  'love holiday monday feeling even go dentists hour',
#  'aight still want get money',
#  'bloomberg message center 447797706009 wait apply future http careers bloomberg com',
#  'soon real thing princess make wet',
#  'laughing out loud oh babe wont sliding place midnight thanks invite',
#  'could keep it simple, stupid feel next',
#  'planning come chennai',
#  'sorry ll call later meeting sir',
#  'home also',
#  'alright thanks advice enjoy night i ma try get sleep',
#  'unique user id 1172 removal send stop 87239 customer services 08708034412',
#  'yeah sure thing mate haunt got stuff sorted im going sound anyway promoting hex by way dont know number joke',
#  'please give 2 pick tuesday evening 8 ok',
#  'finished eating got you plate leftovers time',
#  'probably lt gt',
#  'stop however suggest stays someone able give ors every stool',
#  'urgh coach hot smells chip fat thanks especially duvet predictive text word',
#  'message responce happend',
#  'ya cant display internal subs got ta extract',
#  '3 pa selected',
#  'dear know lt gt th lt gt th birthday loving gopalettan planning give small gift day like participate welcome please contact admin team details',
#  'thanks loving rock',
#  'change windows logoff sound',
#  'also sir sent email log usc payment portal i ll send another message explain things back home great weekend',
#  'alright babe',
#  'well m desperate ll call armand',
#  'wherre s boytoy',
#  'sorry sir call tomorrow senthil hsbc',
#  'hmmm guess go 4 kb n power yoga haha dunno tahan power yoga anot thk got lo oso forgot liao',
#  'ok k sry knw 2 siva tats askd',
#  'great escape fancy bridge needs lager see tomo',
#  'gam gone outstanding innings',
#  'm stuck da middle da row da right hand side da lt',
#  '18 days euro2004 kickoff you kept informed latest news results daily unsubscribe send get euro stop 83222',
#  'you secret admirer looking 2 make contact you find r reveal thinks ur special call 09058094594',
#  'wow love sooo much know barely stand wonder day goes well love think miss',
#  'great trip india bring light everyone project everyone lucky see smile bye abiola',
#  'spending new years brother family lets plan meet next week ready spoiled',
#  'sorry you unsubscribe yet mob offer package min term 54 weeks pls resubmit request expiry reply themob help 4 info',
#  'yunny m goin late',
#  'b4u voucher w c 27 03 marsms log onto www b4utele com discount credit opt reply stop customer care call 08717168528',
#  'dunno lei shd b driving lor cos go sch 1 hr oni',
#  'winner specially selected receive å 1000 cash å 2000 award speak live operator claim call 087123002209am 7pm cost 10p',
#  'much got cleaning',
#  'ok good making money',
#  'everywhere dirt floor windows even shirt sometimes open mouth comes flowing dream world without half chores time joy lots tv shows i ll see guess like things must exist like rain hail mist time done become one',
#  'call like lt gt times oh give us hypertension oh',
#  'going wipro interview today',
#  'dai downloaded exe file run exe installing',
#  'long fuckin showr',
#  'anything lor toa payoh got place 2 walk meh',
#  'somewhere fredericksburg',
#  'knew you slept v late yest wake late',
#  'thanx 4 puttin da fone',
#  'honey boo m missing you',
#  'important message final contact attempt important messages waiting customer claims dept expires 13 4 04 call 08717507382',
#  'nosy guess idk reacting m freaked',
#  'dude s teresa hope okay didnt hear people called received package since dec lt gt thot you ld like know fantastic year best reading plus really really bam first aid usmle work done',
#  'yeah got 2 v apologetic n fallen actin like spoilt child got caught till 2 wo n t go badly cheers',
#  'welp apparently retired',
#  'ultimately tor motive tui achieve korli',
#  'wishing family merry x mas happy new year advance',
#  'aiyah ok wat long got improve already wat',
#  'hi way you 2day normal way real ur unique hope know you 4 rest mylife hope you find wot lost',
#  'see',
#  'many people seems special first sight remain special till last sight maintain till life ends sh jas',
#  'm sure still available though',
#  'm great aunts anniversary party tarpon springs',
#  'lolnice went fish water',
#  'please give us connection today lt decimal gt refund bill',
#  'laughing out loud m hot air balloon',
#  'n t get second half message',
#  'congratulations you claim 2 vip row tickets 2 c blu concert november blu gift guaranteed call 09061104276 claim ts cs www smsco net costå 3 75max',
#  'save stress person dorm account send account details money sent',
#  'garage keys n t bookshelf',
#  'reply name address receive post weeks completely free accommodation various global locations www phb1 com ph 08700435505150p',
#  'give us back id proof lt gt rs wont allow work come home within days',
#  'get cash together ll text jason',
#  'n t think spatula hands',
#  'sorry guess whenever get hold connections maybe hour two ll text',
#  'ok many buy',
#  'ok ask abt e movie you wan ktv oso',
#  'sounds great home',
#  'dont forget place many free requests 1stchoice co uk wish information call 08707808226',
#  'clothes jewelry trips',
#  'farm open',
#  'nope waiting sch 4 daddy',
#  'daily text ûò favour time',
#  'private 2003 account statement 07973788240 shows 800 un redeemed s i m points call 08715203649 identifier code 40533 expires 31 10 04',
#  'sorry trouble you buy 4d dad 1405 1680 1843 2 big 1 small sat n sun thanx',
#  'ok gentleman treat dignity respect',
#  'message free welcome new improved sex dogging club unsubscribe service reply stop msgs 150p 18 only',
#  'beautiful truth gravity read carefully our heart feels light someone feels heavy someone leaves goodmorning',
#  'man bus slow think re gon na get',
#  'nt driving even many reasons called bbd thts chikku hw abt dvg cold heard tht vinobanagar violence hw condition hw ru problem',
#  'ok asked money far',
#  'told going got drunk',
#  'hope great new semester wish best made greatness',
#  'yeah whatever laughing out loud',
#  'like love arrange',
#  'much buzy',
#  'got another job one hospital data analysis something starts monday sure thesis got finished',
#  'girl stay bed girl n t need recovery time id rather pass fun cooped bed',
#  'ard 530 lor ok message ì_ lor',
#  '1 nokia tone 4 ur mob every week txt nok 87021 1st tone free get txtin tell ur friends 150p tone 16 reply hl 4info',
#  'unique enough find 30th august www areyouunique co uk',
#  'thanks talk saturday dear cherish brother role model',
#  'guaranteed å 1000 cash å 2000 prize claim yr prize call customer service representative 08714712394 10am 7pm',
#  'shuhui say change 2 suntec steamboat you noe r you',
#  'objection bf coming',
#  'r you scratching',
#  'think one saying clearly ok leave need ask go come',
#  'sms services inclusive text credits pls gotto www comuk net login 3qxj9 unsubscribe stop extra charge help 08702840625 comuk 220cm2 9ae',
#  'free message thanks using auction subscription service 18 150p msgrcvd 2 skip auction txt 2 unsubscribe txt stop customercare 08718726270',
#  'm ok wif cos like 2 try new things scared you dun like mah cos you said loud',
#  'thanks understanding ve trying tell sura',
#  'stop knowing well',
#  '500 new mobiles 2004 must go txt nokia 89545 collect today å 1 www 4 tc biz 2optout 087187262701 50gbp mtmsg18',
#  'single single answers fighting plus said broke didnt reply',
#  'sweetheart hope kind day one loads reasons smile biola',
#  'first strike red one bird antelope begin toplay fieldof selfindependence believe flower contention grow random',
#  'sucks got planned yo valentine yo valentine n t',
#  'urgent last weekend s draw shows å 1000 cash spanish holiday call 09050000332 claim c rstm sw7 3ss 150ppm',
#  'boooo always work quit',
#  'you re welcome caught you using broken english',
#  'many company tell language',
#  'usual you call ard 10 smth',
#  'hi msg m office',
#  'hey you fancy meetin 4 cha åð hav lil beverage txt ring meet later quite tired got 3 v pist love pete x x x',
#  'oh oh den muz change plan liao go back yan jiu',
#  'sent lt gt bucks',
#  'sexy sexy cum text im wet warm ready porn you fun msg free recd msgs 150p inc vat 2 cancel text stop',
#  'ì_ call 10 10 make sure dat ve woken',
#  'message text missing sender name missing number missing sent date missing missing you lot thats everything missing sent via fullonsms com',
#  'took hooch walk toaday fell splat grazed knees everything stayed home see tomorrow',
#  'reach 9 telling dont know',
#  'pls ask macho much budget bb bold 2 cos saw new one lt gt dollars',
#  'show wot say could you c 4 dust',
#  'carlos pick ll swing usf little bit',
#  'you coming back 4 dinner rite dad ask confirm wif you',
#  'mum s repent',
#  'oh send address',
#  'plan',
#  'ou guaranteed latest nokia phone 40gb ipod mp3 player å 500 prize txt word collect 83355 ibhltd ldnw15h 150p mtmsgrcvd18',
#  'guess spent last night phasing fourth dimension',
#  'pizza you want',
#  's cool ll night lem know re around',
#  'infact happy new year seeing',
#  'december mobile 11mths entitled update latest colour camera mobile free call mobile update co free 08002986906',
#  'm freezing craving ice fml',
#  'future planned tomorrow result today best present enjoy future',
#  'wa ur openin sentence formal anyway m fine juz tt m eatin much n puttin weight haha anythin special happened',
#  'congrats 2 mobile 3g videophones r call 09063458130 videochat wid mates play java games dload polyph music noline rentl',
#  'able anything',
#  'come sec s somebody want see',
#  'tell something thats okay',
#  'wait msg lt gt min',
#  'rolling on the floor laughing true name',
#  'da good good player why unsold',
#  'me 2 babe feel lets 4get it both try cheer up not fit soo muchxxlove you locaxx',
#  'test earlier appreciate call tomorrow',
#  'yes last practice',
#  'got ur favorite oyster n got favorite sashimi ok lar dun say already wait ur stomach start rumbling',
#  'sir waiting letter',
#  'v aluable a ffectionate l oveable e ternal n oble t ruthful i ntimate n atural e namous happy valentines day advance',
#  'hope enjoyed new content text stop 61610 unsubscribe help 08712400602450p provided tones2you co uk',
#  'maybe could get book tomo return immediately something',
#  'thanx4 today cer nice 2 catch ave 2 find time often oh well take care c you soon c',
#  'havent',
#  'born god said oh another idiot born',
#  'helloooo wake sweet morning welcomes you enjoy day full joy gud mrng',
#  'private 2004 account statement 078498 7 shows 786 unredeemed bonus points claim call 08719180219 identifier code 45239 expires 06 05 05',
#  'v nice 2 sheffield tom 2 air opinions categories 2 b used 2 measure ethnicity next census busy transcribing',
#  'm serious money base',
#  'please call amanda regard renewing upgrading current t mobile handset free charge offer ends today tel 0845 021 3680 subject s c s',
#  'okay soon best',
#  'excellent thought misundrstud frnd knw you hate bt day wen you ll knw truth you ll hate urself good night',
#  'love want flood pretty pussy cum',
#  'de call time ill tell k',
#  'hi birth 8lb 7oz mother baby brilliantly',
#  'alright see bit',
#  'sure make sure knows ai n t smokin yet',
#  '1 polyphonic tone 4 ur mob every week txt pt2 87575 1st tone free get txtin tell ur friends 150p tone 16 reply hl 4info',
#  'n t anybody s number still n t thought tactful way ask alex',
#  'coming friday leave pongal get news work place',
#  'ask princess',
#  'awww dat sweet think something nice time tonight ill probably txt you later cos im lonely xxx',
#  'dunno da next show aft 6 850 toa payoh got 650',
#  'sis lor juz watched italian job',
#  'picked receipt something earlier',
#  'k k performed',
#  'late need go n get da laptop',
#  'tried call reply sms video mobile 750 mins unlimited text free camcorder reply call 08000930705',
#  'you',
#  'valued customer pleased advise following recent review mob awarded å 1500 bonus prize call 09066368470',
#  'smile pleasure smile pain smile trouble pours like rain smile sum1 hurts you smile becoz someone still loves see you smiling',
#  'm office da',
#  'mm yes dear look hugging p',
#  'yup',
#  'erm û_ ill pick 6 45pm ll give enough time get park',
#  'aight 8 latest probably closer 7 jay tyler two trips',
#  'check nuerologist',
#  'auction round 4 highest bid å 54 next maximum bid å 71 bid send bids e g 10 bid å 10 83383 good luck',
#  '1apple day no doctor 1tulsi leaf day no cancer 1lemon day no fat 1cup milk day no bone problms 3 litres watr day no diseases snd ths 2 you care',
#  'wat makes you thk ll fall actually thk m quite prone 2 falls lucky dad home ask come n fetch already',
#  'said matter mind saying matter',
#  'wonder cos dun rem seeing silver car thk saw black one',
#  'jokin oni lar ìï busy wun disturb ì_',
#  'thanx birthday already',
#  'hi wkend ok journey terrible wk good huge back log marking',
#  's good lets thank god please complete drug lots water beautiful day',
#  'laughing out loud boo hoping laugh',
#  'yup thk r e teacher said make face look longer darren ask 2 cut short',
#  'buy one egg da please',
#  'yeah probably',
#  'delhi chennai still silent',
#  'pen thing beyond joke wont biro n t masters ca n t ever',
#  'wats ur opinion abt abt character',
#  'you ever get song stuck head reason wo n t go away til you listen like 5 times',
#  'n t forget owns s private property good boy always passionate keep it simple, stupid',
#  'problem spending lot quality time together',
#  'unbelievable faglord',
#  'full heat pa applyed oil pa',
#  'meeting you work tel shall work tomorrow',
#  'cheers message zogtorius iåõve staring phone age deciding whether text',
#  'busy trying finish new year looking forward finally meeting',
#  'ok c ya',
#  'call unable cal lets meet bhaskar deep',
#  '1st wk free great! tones str8 2 you wk txt nokia 8007 classic nokia tones hit 8007 polys nokia 150p poly 200p 16',
#  'dont know jabo abi',
#  'wont touch permission',
#  'wan na watch movie',
#  'pic please re send',
#  'shhhhh nobody supposed know',
#  'ok ok take care understand',
#  'felt conveying reason ese',
#  'nt yet chikku simple habba hw abt you',
#  'sorry da thangam it s mistake',
#  'sleeping surfing',
#  'da whats plan',
#  'yay ca n t wait party together',
#  'g wants know fuck',
#  'tell said eat shit',
#  'use foreign stamps country',
#  'aight let know re gon na around usf',
#  'thank winner notified sms good luck future marketing reply stop 84122 customer services 08450542832',
#  'december mobile 11mths entitled update latest colour camera mobile free call mobile update vco free 08002986906',
#  'hi di yijue re meeting 7 pm esaplanade tonight',
#  'thanx 4 sending home',
#  'ur sis',
#  'yeah gang ready',
#  'dear 0776xxxxxxx you ve invited xchat final attempt contact you txt chat 86688 150p msgrcvdhg suite342 2lands row w1j6hl ldn 18yrs',
#  'ok tell stay yeah tough optimistic things improve month',
#  'yunny m walking citylink ì_ faster come hungry',
#  'dice art class 6 thru 9 thanks though idea time come tomorrow',
#  'you go phone gon na die stay',
#  'nice day today love dearly',
#  'oh yah never cancel leh haha',
#  'sorry cant take call right happens r 2waxsto wat want come ill get medical insurance ll able deliver basic care m currently shopping right medical insurance give til friday morning thats i ll see major person guide right insurance',
#  'date sunday',
#  'yes many sweets',
#  'you want come back a beautiful necklace token heart you thats give wife liking be see one give that dont call me i wait till come',
#  'wen ur lovable bcums angry wid you dnt take seriously coz angry childish n true way showing deep affection care n luv kettoda manda nice day da',
#  'frnd juz word merely relationship silent promise says wherevr whenevr forevr gudnyt dear',
#  'discount code rp176781 stop messages reply stop www regalportfolio co uk customer services 08717205546',
#  'oh charge camera',
#  'forwarded 21870000 hi mailbox messaging sms alert 40 matches please call back 09056242159 retrieve messages matches cc100p min',
#  'depends would like treated',
#  'wish you feel alone',
#  'happened interview',
#  'means got epi she s fine she s',
#  'for sparkling shopping breaks 45 per person call 0121 2025050 visit www shortbreaks org uk',
#  'hmmm but give one day',
#  'detroit home snow enjoy',
#  'what youdoing later sar xxx',
#  'ful song lyrics',
#  'kate jackson rec center 7ish right',
#  'see knew giving break times woul lead always wanting miss curfew gon na gibe til one midnight movie gon na get til 2 need come home need getsleep anything need b studdying ear training',
#  'always make things bigger',
#  'sry ca n t talk phone parents',
#  'thing r good thanx got exams march ive done revision fran still boyf ive got ta interviw 4 exeter bit worried x',
#  'huh slow tot you reach long ago liao you 2 days 4 leh',
#  'r ì_ going 4 today s meeting',
#  'aight sounds good want come',
#  'actually getting ready leave house',
#  'house e sky quite dark liao raining got excuse 2 run already rite hee',
#  'guaranteed latest nokia phone 40gb ipod mp3 player å 500 prize txt word collect 83355 ibhltd ldnw15h 150p mtmsgrcvd18',
#  'get ready lt gt inches pleasure',
#  'forced eat slice m really hungry tho sucks mark getting worried knows m sick turn pizza laughing out loud',
#  'like think s always possibility pub later',
#  'sent jd customer service cum accounts executive ur mail id details contact us',
#  'good day mine really busy much tomorrow night',
#  'ok lor you wan go look 4 you',
#  'went fast asleep dear take care',
#  'many happy returns day wish happy birthday',
#  'ree entry 2 weekly comp chance win ipod txt pod 80182 get entry std txt rate c s apply 08452810073 details 18',
#  'hey elaine today s meeting still',
#  'yes really great bhaji told kallis best cricketer sachin world very tough get',
#  'nothin comes mind ìï help buy hanger lor ur laptop heavy',
#  'much would cost hire hitman',
#  'havent mus ask you 1st wat meet 4 lunch den you n meet already lor you wan 2 go ask da ge 1st confirm w as soon as possible',
#  'you free sat rite you wan 2 watch infernal affairs wif n darren n mayb xy',
#  'tot you outside cos darren say you come shopping course nice wat jus went sim lim look mp3 player',
#  'know mood today',
#  'nah m perpetual dd',
#  'oh yeah forgot you take 2 shopping',
#  'im gonnamissu much would say il send you postcard buttheres aboutas much chance merememberin asthere ofsi breakin contract luv yaxx',
#  'height oh shit situation guy throws luv letter get a life falls brothers head whos gay',
#  'still chance search hard get let try',
#  's lag s sad part keep touch thanks skype',
#  'oh fuck s sake s like tallahassee',
#  'recpt 1 3 ordered ringtone order processed',
#  'customer service annoncement new years delivery waiting please call 07046744435 arrange delivery',
#  'finished missing plenty',
#  '85233 free ringtone reply real',
#  'nah s straight bring bud drinks something s actually little useful straight cash',
#  'wait know wesleys town bet hella drugs',
#  'telly brdget jones',
#  'time month mid time',
#  'well weather cali s great complexities great need car move freely taxes outrageous great place sad part missing home',
#  'nah wednesday bring mini cheetos bag',
#  'tonight yeah d',
#  'okey dokey i û ll bit sorting stuff',
#  'came hostel',
#  'ta daaaaa home babe still',
#  'free top ringtone sub weekly ringtone get 1st week free send subpoly 81618 3 per week stop sms 08718727870',
#  'eat fo lunch senor',
#  'tmr ì_ brin lar aiya later come n c lar mayb ì_ neva set properly ì_ got da help sheet wif ì_',
#  'thank you',
#  'thanks honey still n t heard anything leave bit longer 2 crowd try later great advice thanks hope cardiff still',
#  'aight text tonight ll see s',
#  'right brah see later',
#  'lt gt k oh send home sale',
#  'much textin bout',
#  'jesus christ bitch m trying give drugs answer fucking phone',
#  'laughing out loud really need remember eat m drinking appreciate keeping company night babe smiles',
#  'laughing out loud know re dramatic schools already closed tomorrow apparently ca n t drive inch snow supposed get',
#  'today s offer claim ur å 150 worth discount vouchers text yes 85023 savamob member offers mobile cs 08717898035 å 3 00 sub 16 unsub reply x',
#  'hmmm still dont opener',
#  'k tell anything',
#  'sac score big hundred he set batsman',
#  'want keep it simple, stupid feel next',
#  'case guess ll see campus lodge',
#  'll tough ll',
#  'cant think anyone spare room top head',
#  'desires you going doctor 4 liver get bit stylish get ur hair managed thats',
#  'hey tmr meet bugis 930',
#  'laugh my a.. off s fish memory need',
#  'xy ur car you picking',
#  'last chance claim ur å 150 worth discount vouchers today text shop 85023 savamob offers mobile cs savamob pobox84 m263uz å 3 00 sub 16',
#  'would smoking help us work difficult time',
#  'saw ron burgundy captaining party boat yeah',
#  'yes tv always available work place',
#  'castor need see something',
#  'oh love s soooo good hear omg missed much today m sorry problems provider thank tming',
#  'marriage function',
#  'thank much selflessness love plenty',
#  'whatsup dont you want sleep',
#  'time coming later',
#  'ok give 5 minutes think see by the way re alibi cutting hair whole time',
#  'even friend priest call',
#  'sounds like could lot time spent chastity device boy grins take beatings like good dog going lounge nice long bath',
#  'shuhui bought ron s present s swatch watch',
#  'make sure alex knows birthday fifteen minutes far re concerned',
#  'haha yeah 2 oz kind shitload',
#  's significant dont worry',
#  'n t enough trouble sleeping',
#  'sex ur mobile free sexy pic jordan text babe 88600 every wk get sexy celeb pocketbabe co uk 4 pics 16 å 3 wk 087016248',
#  'hi harish s rent transfred ur acnt',
#  'yay finally laughing out loud missed cinema trip last week',
#  'anything specific regards jaklin idk fuck',
#  'sorry ca n t help',
#  'hi babe you r likely bed im sorry tonight really wan na see you tomorrow call 9 love xxx',
#  'abeg make profit start using get sponsors next event',
#  'waiting call',
#  'hey sathya till dint meet even single time saw situation sathya',
#  'say bold torch later one torch 2bold',
#  'gosh pain spose better come',
#  'yun ah now ì_ wkg by the way ì_ go nus sc ìï wana specialise wad',
#  'haha yup hopefully lose kg mon hip hop go orchard weigh',
#  'fuck babe miss sooooo much wish sleep bed lonely go sleep dream love',
#  'marvel mobile play official ultimate spider man game å 4 50 ur mobile right text spider 83338 game send you free 8ball wallpaper',
#  'callin say hi take care bruv',
#  'know god created gap fingers one made comes amp fills gaps holding hand love',
#  'probably want pick',
#  'keep ur problems ur heart',
#  'someonone know trying contact via dating service find could call mobile landline 09064015307 box334sk38ch',
#  'you ûªve bin awarded å 50 play 4 instant cash call 08715203028 claim every 9th player wins min å 50 å 500 optout 08718727870',
#  'whole car appreciated last two dad map reading semi argument apart things going ok p',
#  'watching tv lor nice one like lor',
#  'k k apo k good movie',
#  'download clear movies dvd copies',
#  'aah cuddle would lush d need lots tea soup kind fumbling',
#  'ya one slow poo',
#  'raviyog peripherals bhayandar east',
#  'sch neva mind you eat 1st lor',
#  'download many ringtones you like restrictions 1000s 2 choose you even send 2 yr buddys txt sir 80082 å 3',
#  'want send something sell fast lt gt k easy money',
#  'todays vodafone numbers ending 4882 selected receive å 350 award number matches call 09064019014 receive å 350 award',
#  'anything lor juz us lor',
#  'whens radio show',
#  'oh dang n t mean send laughing out loud',
#  'teach apps da come college',
#  'chance might evaporated soon violated privacy stealing phone number employer s paperwork cool please contact report supervisor',
#  '88800 89034 premium phone services call 08718711108',
#  'people see msgs think iam addicted msging wrong bcoz don t know iam addicted sweet friends bslvyl',
#  'lost 10 kilos today',
#  '1000 s girls many local 2 you r virgins 2 r ready 2 4fil ur every sexual need you 4fil text cute 69911 å 1 50p',
#  'oh k got job whats',
#  'idk m sitting stop shop parking lot right bawling eyes feel like m failure everything nobody wants feel like m failing',
#  'spoke uncle john today strongly feels need sacrifice keep s going call beg listen dont make promises make clear things easy need please let us work things long keep expecting help creativity stifled pls keep happy promises part',
#  'good morning im suffering fever dysentry able come office today',
#  'know taj mahal symbol love lesser known facts 1 mumtaz shahjahan s 4th wife 7 wifes 2 shahjahan killed mumtaz s husband marry 3 mumtaz died lt gt th delivery 4 married mumtaz s sister question arises hell love the great hari',
#  'aight ve set free think could text blake s address occurs m quite sure m thought',
#  'ìï v fan',
#  'free msg ringtone http tms widelive com index wml id 1b6a5ecef91ff9 37819 first true18 0430 jul 05',
#  'you ask next sat make m ok lor',
#  'dont much image class',
#  'one week leave put know time',
#  'okay ve seen pick friday',
#  'walked hour 2 c you doesnåõt show care wont you believe im serious',
#  'yup havent want go yoga call book',
#  'thanks reply today ur visa coming r you still buying gucci bags sister things easy uncle john also bills really need think make money later sha',
#  'effect irritation ignore',
#  'love',
#  'well might come',
#  'ok you enjoy ur shows',
#  'hey got mail',
#  'dizzamn aight ll ask suitemates get back',
#  'heard abt tat',
#  'kent vale lor ìï wait 4 ar',
#  'cos darren say ì_ considering mah ask ì_',
#  'enjoy ur life good night',
#  'n t b floppy b snappy happy gay chat service photo upload call 08718730666 10p min 2 stop texts call 08712460324',
#  'meeting da call',
#  'want funk ur fone weekly new tone reply tones2u 2 text www ringtones co uk original n best tones 3gbp network operator rates apply',
#  'yet ya sapna aunty manege y day hogidhe chinnu full weak swalpa black agidhane',
#  'still west coast haiz ìï ll take forever come back',
#  'laughing out loud well quality aint bad aint complaining',
#  'free call sir',
#  'wake lt gt morning',
#  'you still going mall',
#  'aight ll work thanks',
#  'n t plan staying night prolly wo n t back til late',
#  'watching house ûò entertaining ûò getting whole hugh laurie thing ûò even stick ûò indeed especially stick',
#  'lost 4 pounds since doc visit last week woot woot m gon na celebrate stuffing face',
#  'ok prob take ur time',
#  'match started india lt gt 2',
#  'pls dont forget study',
#  'end might still vomit okay everything come',
#  'important prevent dehydration giving enough fluids',
#  'trying figure m suppose see couple different people week said d get together n t set dates',
#  'come home n t want you miserable',
#  'smile right go world wonder smiling think crazy keep away grins',
#  'you wake already thanx 4 e tau sar piah s quite nice',
#  'squeeeeeze christmas hug you lik frndshp den hug back you get 3 you r cute 6 you r luvd 9 you r lucky none people hate you',
#  'want 750 anytime network mins 150 text new video phone five pounds per week call 08002888812 reply delivery tomorrow',
#  'big brother alert computer selected you 10k cash 150 voucher call 09064018838 ntt po box cro1327 18 bt landline cost 150ppm mobiles vary',
#  'dear got lt gt dollars hi hi',
#  'carlos says pick later yeah re set',
#  'ok im sure time finish tomorrow wan na spend evening cos would vewy vewy lubly love xxx',
#  'loosu go hospital de dont let careless',
#  'tell you headache want use 1 hour sick time',
#  'send id password',
#  'ok let you noe leave house',
#  'yeah probably sure ilol let you know personally wuldnt bother ur goin mite well',
#  'white fudge oreos stores',
#  'text banneduk 89555 see cost 150p textoperator g696ga 18 xxx',
#  'still work going small house',
#  'ah see lingo let know wot earth finished making',
#  'good morning dear great amp successful day',
#  'll minor shindig place later tonight interested',
#  'water logging desert geoenvironmental implications',
#  'home always chat',
#  'hurt tease make cry end life die plz keep one rose grave say stupid miss you nice day bslvyl',
#  'm driving raining ll get caught e mrt station lor',
#  'leave wif lar ìï wan carry meh heavy da num 98321561 familiar ì_',
#  'plans family set stone',
#  'tot you reach liao said t shirt',
#  'ya told asking wats matter',
#  'text82228 get ringtones logos games www txt82228 com questions info txt82228 co uk',
#  'stupid auto correct phone',
#  'finally happened aftr decades beer cheaper petrol goverment expects us drink n t drive',
#  'raji pls favour pls convey birthday wishes nimya pls today birthday',
#  'ha ha cool cool chikku chikku db',
#  'hi dear saw dear happy battery low',
#  'please call 08712402578 immediately urgent message waiting',
#  'ok also wan 2 watch e 9 pm show',
#  'midnight earliest',
#  'ages s abj',
#  'messages food',
#  'actually fuck whatever find excuse tampa point january though',
#  'im inperialmusic listening2the weirdest track ever byåóleafcutter johnåó sounds like insects molested someone plumbing remixed evil men acid',
#  'hey really horny want chat see naked text hot 69698 text charged 150pm unsubscribe text stop 69698',
#  'ok lor go tog lor',
#  '4 costa del sol holiday å 5000 await collection call 09050090044 toclaim sae tc pobox334 stockport sk38xh costå 1 50 pm max10mins',
#  'oh yeah clearly s fault',
#  'cool want go kappa meet outside mu',
#  '1 n t number 2 gon na massive pain ass d rather get involved s possible',
#  'k for your information x ride early tomorrow morning s crashing place tonight',
#  'mmmmm loved waking words morning miss love hope day goes well happy wait us together',
#  'alright ll head minutes text meet',
#  'dun believe wat',
#  'i û ve got salt rub open wounds like',
#  'yo howz you girls never rang india l',
#  'need buy lunch eat maggi mee',
#  'ha don û t know either clever simple thing pears day perfect christmas',
#  'ì_ wan 2 meet n combine parts s da rest da project going',
#  'hey happen de alright',
#  'good sleep rhythm person establish rhythm body learn use want know',
#  'tell re female v re throwing re deciding get',
#  'ok ok ok whats ur todays plan',
#  'shall ask one thing dont mistake',
#  'sure get acknowledgement s astoundingly tactless generally faggy demand blood oath fo',
#  'urgent trying contact you todays draw shows å 800 prize guaranteed call 09050003091 land line claim c52 valid12hrs',
#  'popping lt gt ibuprofens help',
#  'ringtone club great! new polys direct mobile every week',
#  'wait s still clear sure sarcastic s x n t want live us',
#  'hi customer loyalty offer new nokia6650 mobile å 10 txtauction txt word start 81151 get 4t ctxt tc 150p mtmsg',
#  'babe need advice',
#  'like italian food',
#  'ofcourse also upload songs',
#  'sent email ûò address incomm right',
#  'fact re cleaning shows know m upset priority constantly what want',
#  'hello hun ru way im good 2 dates guy met walkabout far meet soon hows everyone else',
#  'hey hey werethe monkeespeople say monkeyaround howdy gorgeous',
#  'dude you knw also telugu thts gud k gud nyt',
#  'samus shoulders yet',
#  'wewa 130 iriver 255 128 mb',
#  'freemsg feelin kinda lnly hope you like 2 keep company jst got cam moby wan na c pic txt reply date 82242 msg150p 2rcv hlp 08712317606 stop 82242',
#  'glad talking',
#  'oh k come tomorrow',
#  'told tell stupid hear wont tell anything dad called brother spoken',
#  'project pa come',
#  'hi re re keen go kind feel n t go tomo n t mind',
#  'train back northampton m afraid',
#  'ha must walk everywhere take tram cousin said walk vic market hotel',
#  'wot you 2 you weirdo',
#  'went attend another two rounds today still did t reach home',
#  'aslamalaikkum insha allah tohar beeen muht albi mufti mahfuuz meaning',
#  'said ì_ dun haf passport smth like dat ì_ juz send email account',
#  'thinking chuckin ur red green n black trainners 2 save carryin bac train',
#  'competition',
#  'honey sweetheart darling sexy buns sugar plum loverboy miss boytoy smacks ass go gym',
#  'hello handsome finding job lazy working towards getting back net mummy s boytoy miss',
#  'wake since checked stuff saw true available spaces pls call embassy send mail',
#  'shant disturb you anymore jia',
#  'hope s result consistently intelligent kind start asking practicum links keep ears open best talk to you later',
#  'hi da todays class',
#  'enjoy watching playing football basketball anything outdoors',
#  'miss ya need ya want ya love ya',
#  'short cute good person',
#  'pass dis ur contacts n see wat you get red m luv wid you blue you put smile face purple you r realy hot pink you r swt orange thnk lyk you green realy wana go wid you yelow wnt you bck black m jealous you brown miss nw plz giv one color',
#  'yes mum lookin strong',
#  '545 lor ya go 4 dinner together',
#  'da happy sit together na',
#  's taxt massage tie pos argh ok lool',
#  'laughing out loud well n t without could big sale together',
#  'ok pa nothing problem',
#  'wan na art',
#  'm outside islands head towards hard rock ll run',
#  'oh grand bit party n t mention cover charge s probably first come first served',
#  'yeah laughing out loud luckily n t starring role like',
#  'great hope like man well endowed lt gt inches',
#  'yes baby need stretch open pussy',
#  'ok chikku 1 favourite song',
#  'huh 6 also many mistakes',
#  'urgent trying contact last weekends draw shows å 900 prize guaranteed call 09061701851 claim code k61 valid 12hours',
#  'work week',
#  'happen dear tell',
#  'number vivek',
#  'yes last week m taking live call',
#  'aight see bit',
#  'ya ì_ taking ure practical lessons start june',
#  'dude avatar 3d imp one point thought actually flies room almost tried hittng one reflex',
#  'responding',
#  'ur balance å 500 ur next question sang uptown girl 80 s 2 answer txt ur answer 83600 good luck',
#  'ready big day tomorrow',
#  'know watching film computer',
#  'hi chachi tried calling you unable reach you pl give missed cal you c tiz msg kanagu',
#  'god bless get good sleep dear pray',
#  'm gon na able late notice ll home weeks anyway plans',
#  'laugh my a.. off ok wont needing you hair anymore',
#  'yup',
#  'dhoni luck win big title so win',
#  'reply win å 100 weekly 2006 fifa world cup held send stop 87239 end service',
#  'much bad avoid like',
#  'oh yes ve little weather ve kind coccooning home',
#  'doesnt make sense take unless free need know wikipedia com',
#  '87077 kick new season 2wks free goals news ur mobile txt ur club name 87077 eg villa 87077',
#  'uncles atlanta wish guys great semester',
#  'mah b ll pick tomorrow',
#  'ok lor anyway thk cant get tickets cos like quite late already you wan 2 go look 4 ur frens darren wif',
#  'tuition 330 hm go 1120 1205 one mind',
#  'hey mr going sea view couple gays mean games give bell ya finish',
#  'baaaaabe misss youuuuu go teach class 5',
#  'm good movie ok leave hourish',
#  'aight plan come later tonight',
#  'lay man let know missed thought great day send bimbo ugo s numbers ill appreciate safe',
#  'want grasp pretty booty',
#  'haha kidding papa needs drugs',
#  'yes princess want catch big strong hands',
#  'gent trying contact last weekends draw shows å 1000 prize guaranteed call 09064012160 claim code k52 valid 12hrs 150ppm',
#  'ok come home vl nice meet v chat',
#  'ur ringtone service changed 25 free credits go club4mobiles com choose content stop txt club stop 87070 150p wk club4 po box1146 mk45 2wt',
#  'wat late still early mah juz go 4 dinner lor aiya dunno',
#  'can please come imin town dontmatter urgoin outl8r',
#  'true passable get high score apply phd get 5years salary makes life easier',
#  's love hear v see sundayish',
#  'congrats 1 year special cinema pass 2 call 09061209465 c suprman v matrix3 starwars3 etc 4 free bx420 ip4 5we 150pm dont miss',
#  'nothing much chillin home super bowl plan',
#  'quite late lar ard 12 anyway wun b drivin',
#  'private 2003 account statement shows 800 un redeemed s i m points call 08718738002 identifier code 48922 expires 21 11 04',
#  'nope ll come online',
#  'ola would get back maybe today told direct link us getting cars bids online arrange shipping get cut you partnership you invest money shipping takes care rest you wud b self reliant soon dnt worry',
#  'not enufcredeit tocall shall ileave uni 6 get bus yor house',
#  'laughing out loud real told dad cancer',
#  'done handed n t know mega shop asda counts celebration thats m',
#  'oh sorry please',
#  'would great ll guild could meet bristol road somewhere get touch weekend plans take flight good week',
#  'still getting goods',
#  'alright re set text man',
#  'purchase stuff today mail po box number',
#  'private 2003 account statement shows 800 un redeemed s i m points call 08718738001 identifier code 49557 expires 26 11 04',
#  'friend got says s upping order grams s got lt gt get',
#  'great safe trip dont panic surrender',
#  'dear reached railway happen',
#  'get gift year didnt get anything bad',
#  'plm come da way',
#  'hey told name gautham ah',
#  'working ringing you thing whole houseful screaming brats pulling hair loving you',
#  'reason team budget available last buy unsold players base rate',
#  'k k give treat',
#  'freemsg fancy flirt reply date join uks fastest growing mobile dating service msgs rcvd 25p optout txt stop 83021 reply date',
#  'better bb wont use wife doctor',
#  'you noe 2 send files 2 computers',
#  'love cuddle want hold strong arms right',
#  'laptop take',
#  'babe goes day sip cappuccino think love send keep it simple, stupid across sea',
#  'way office da',
#  'reason ve spoken year anyways great week best exam',
#  'you awake snow',
#  'you hiding stranger',
#  'good afternoon love good see words ym get tm smart move slave smiles drink coffee await',
#  'lookatme thanks purchase video clip lookatme ve charged 35p think better send video mmsto 32323',
#  'ok darlin supose ok worry much i film stuff mate babysit call there xx',
#  'vikky come around lt time gt',
#  'dear subscriber ur draw 4 å 100 gift voucher b entered receipt correct ans elvis presleys birthday txt answer 80062',
#  'wot student discount you get books',
#  'm aight wat s happening side',
#  'dont want hear anything',
#  'nothing getting msgs dis name wit different s',
#  'waaaat lololo ok next time',
#  'got message ignoring yes shopping',
#  'symptoms you love 1 you like listening songs 2 you get stopped you see name beloved 3 you wo n t get angry',
#  'k call ah',
#  'ok chinese food way get fat re paying lipo',
#  'howz pain it come today do said ystrday ice medicine',
#  'watching tv got new job',
#  'sounds good fingers makes difficult type',
#  'norm tomorrow finish 4 15 cos st tests need sort library stuff point tomo got letter today access til end march better get move',
#  'maybe westshore hyde park village place near house',
#  's ur paper',
#  'yup shd haf ard 10 pages add figures ìï got many pages',
#  '2nd time tried 2 contact you you å 750 pound prize 2 claim easy call 087187272008 now1 10p per minute bt national rate',
#  'well good morning mr hows london treatin ya treacle',
#  'okie ì_ wan meet bishan cos bishan m driving today',
#  'nowadays people notixiquating laxinorficated opportunity bambling entropication ever oblisingately opted ur books masteriastering amplikater fidalfication champlaxigating think atrocious wotz ur opinion junna',
#  'dunno lei neva say',
#  'hi ur lookin 4 saucy daytime fun wiv busty married woman free next week chat 2 sort time 09099726429 janinexx callså 1 minmobsmorelkpobox177hp51fl',
#  'hurry home soup done',
#  'time come tomorrow',
#  'yes rent expensive way save',
#  's trouble classes go well re due dodgey one û_ expecting mine tomo see recovery time place',
#  '1000 s flirting txt girl bloke ur name age eg girl zoe 18 8007 join get chatting',
#  'fuck babe happened come never came back',
#  'thank generally date brothas',
#  'havent lei next mon',
#  'certainly puts things perspective something like happens',
#  'yeah probably earlier',
#  'ill call evening ill ideas',
#  'maybe say hi find got card great escape wetherspoons',
#  'thought put back box',
#  'll text carlos let know hang',
#  'heard job m going wildlife talk tonight you want2come that2worzels wizzle whatever',
#  'dear angry busy dear',
#  'could read love answered',
#  'm class holla later',
#  'oooh bed ridden ey thinking',
#  'yes princess want please every night wish command',
#  'nobody decide eat dad wants chinese',
#  'nokia phone lovly',
#  'released vday shirts you put makes bottom half naked instead white underwear',
#  'let want house 8am',
#  'single line big meaning miss anything 4 ur best life',
#  'jot things want remember later',
#  'madam regret disturbance might receive reference check dlf premarica kindly informed rgds rakhesh kerala',
#  'want please inside outside bedroom',
#  'congratulations ur awarded 500 cd vouchers 125gift guaranteed free entry 2 100 wkly draw txt music 87066 tncs www ldew com1win150ppmx3age16',
#  '1 new voicemail please call 08719181503',
#  'tick tick tick could die loneliness know pouts stomps feet need',
#  'come medical college 7pm forward da',
#  'come mu re sorting narcotics situation',
#  'might want pull case plan spending n t much confidence derek taylor s money management',
#  'way send shade s stuff wonderful',
#  'sorry roommates took forever ok come',
#  'waqt se pehle naseeb se zyada kisi ko kuch nahi milta zindgi wo nahi jo hum sochte hai zindgi wo hai jo ham jeetey hai',
#  'free entry gr8prizes wkly comp 4 chance win latest nokia 8800 psp å 250 cash every wk txt great 80878 http www gr8prizes com 08715705022',
#  'tried contact response offer new nokia fone camcorder hit reply call 08000930705 delivery',
#  'pity mood suggestions',
#  'cmon babe make horny turn txt fantasy babe im hot sticky need replies cost å 1 50 2 cancel send stop',
#  'food',
#  'er yep sure props',
#  'happy birthday dear with lots love rakhesh nri',
#  'yup ok',
#  'nice pubs near frankie n bennys near warner cinema',
#  'aight ll grab something eat text re back mu',
#  'babe love covers face kisses',
#  'engalnd telly decided wo n t let watch mia elliot kissing damn',
#  'let know contact ve settled room lets know ok',
#  'umma life vava umma love lot dear',
#  'doc prescribed morphine cause pain meds n t enough waiting mom bring med kick fast m gon na try later',
#  'send text ll skype later',
#  'tell rob mack gf theater',
#  'boltblue tones 150p reply poly mono eg poly3 1 cha cha slide 2 yeah 3 slow jamz 6 toxic 8 come stop 4 tones txt',
#  'drive read need write',
#  'wake gt',
#  'either idea s know anyplaces something',
#  'yoyyooo you know change permissions drive mac usb flash drive',
#  'urgent please call 09066612661 landline å 5000 cash luxury 4 canary islands holiday await collection cs sae award 20m12aq 150ppm 16 ûï',
#  'oh come ah',
#  'laughing out loud you still feeling sick',
#  'yes princess toledo',
#  'yeah ll try scrounge something',
#  'okay wait ah',
#  'hi kate you give ring as soon as possible xxx',
#  'ur cash balance currently 500 pounds maximize ur cash in send go 86688 150p msg cc 08718720201 hg suite342 2lands row w1j6hl',
#  'stop story ve told ve returned s saying order',
#  'well know z take care worries',
#  'got c lazy type forgot ì_ lect saw pouch like v nice',
#  'womdarfull actor',
#  'jus telling you dat ll b leaving 4 shanghai 21st instead ll haf time 2 meet see you',
#  'around still asleep v',
#  'yup lunch buffet you eat already',
#  'urgent trying contact you todays draw shows å 800 prize guaranteed call 09050001808 land line claim m95 valid12hrs',
#  'something you ate',
#  'best watch say cause get drunk motherfucker',
#  'n t go tell friend re sure want live smokes much spend hours begging come smoke',
#  'still customer place',
#  '2nd attempt contract you weeks top prize either å 1000 cash å 200 prize call 09066361921',
#  'except theres chick huge boobs',
#  'stalking you',
#  'like personal sized',
#  'hey gave photo registered driving ah tmr wan na meet yck',
#  'anything lor',
#  'know people still town',
#  'looks like you wil b getting headstart im leaving bout 2 30ish you r desperate company could head earlier we goin meet rummer',
#  'want latest video handset 750 anytime network mins half price line rental reply call 08000930705 delivery tomorrow',
#  'got lousy sleep kept waking every 2 hours see cat wanted come worry cold',
#  'yes appt',
#  'sorry da today wont come play driving clas',
#  'time coming',
#  'dnt worry use ice pieces cloth pack also take 2 tablets',
#  'prakesh know',
#  'r you cooking dinner',
#  'ron say fri leh n said ding tai feng cant make reservations said wait lor',
#  'stupid say challenge god you dont think write instead respond immed',
#  'izzit still raining',
#  'married local women looking discreet action 5 real matches instantly phone text match 69969 msg cost 150p 2 stop txt stop bcmsfwc1n3xx',
#  'dont worry guess s busy',
#  'mmmm cant wait lick',
#  'hi happy birthday hi hi hi hi hi hi hi',
#  'long applebees fucking take',
#  'tell reached',
#  'thats cool gentleman treat dignity respect',
#  'borrow ur bag ok',
#  'say happen',
#  'you goin 2nite',
#  'free 1st week no1 nokia tone 4 ur mobile every week txt nokia 8077 get txting tell ur mates www getzed co uk pobox 36504 w45wq 16 norm150p tone',
#  'aww must nearly dead well jez iscoming todo workand whilltake forever',
#  'ok lor',
#  'nothing you dinner w us',
#  'think i û m waiting bus inform get ever get',
#  'guess somebody know secretly fancies wan na find give us call 09065394973 landline datebox1282essexcm61xn 150p min 18',
#  'happened adventuring',
#  'm happy babe woo hoo party dude',
#  'know people hit fuck yes',
#  'directly behind abt 4 rows behind ì_',
#  'todays voda numbers ending 7548 selected receive 350 award match please call 08712300220 quoting claim code 4041 standard rates app',
#  'rightio 11 48 well arent bright early morning',
#  'need drug anymore',
#  'ok called mom instead fun',
#  'm really sorry wo n t b able 2 friday hope you find alternative hope yr term s going ok',
#  'good stuff',
#  'orh tot you say still dun believe',
#  'guaranteed å 1000 cash å 2000 prize claim yr prize call customer service representative 08714712379 10am 7pm cost 10p',
#  'wen get spiritual deep s great',
#  '0a networks allow companies bill sms responsible suppliers',
#  'aiyah you ok already lar e nydc wheellock',
#  'babe lost try rebooting',
#  'free video camera phones half price line rental 12 mths 500 cross ntwk mins 100 txts call mobileupd8 08001950382 call2optout 674',
#  'yep like pink furniture tho',
#  'ok come ur home half hour',
#  'ride equally uneventful many pesky cyclists around time night',
#  'wish holding tightly making see important much mean much need life',
#  'nice day dear',
#  'yes come nyc audiitions trying relocate',
#  'actual exam harder nbme',
#  'hanks lotsly',
#  'purity friendship two smiling reading forwarded message smiling seeing name gud evng',
#  'k k good going',
#  'cant wait see photos useful',
#  'knock knock txt whose 80082 enter r weekly draw 4 å 250 gift voucher 4 store yr choice cs www tkls com age16 stoptxtstopå 1 50 week',
#  'christmas occasion celebrated reflection ur values desires affections amp traditions ideal christmas',
#  'okie thanx',
#  'k k m going tirunelvali week see uncle already spend amount taking dress so want money i give feb 1',
#  'summers finally fancy chat flirt sexy singles yr area get matched reply summer free 2 join optout txt stop help08714742804',
#  'good time nice something bit different weekends change see ya soon',
#  'laughing out loud mad first woke gave',
#  'message truro hospital ext phone phone side',
#  'see half hour',
#  'thought could go dinner ll treat seem ok',
#  'thank god bed',
#  'pls clarify back open return ticket preponed go back kerala',
#  'yup studying surfing lor m e lazy mode today',
#  'plz note anyone calling mobile co amp asks you type lt gt lt gt disconnect call coz iz attempt terrorist make use sim card itz confirmd nokia n motorola n verified cnn ibn',
#  'm reading text sent meant joke read light',
#  'dint touch',
#  'yo yo yo byatch whassup',
#  'sure stomach',
#  'chinatown got porridge claypot rice yam cake fishhead beehoon either eat cheap den go cafe n tok go nydc somethin',
#  'll join lt gt bus',
#  'yes outside like 2 hours called whole family wake cause started 1',
#  'bishan lar nearer need buy early cos buy got ta park car',
#  'e msg jus you said thanks gift',
#  'use foreign stamps country good lecture',
#  'you knw dis lt gt',
#  'ok april cant wait',
#  'receiving week s triple echo ringtone shortly enjoy',
#  'need come home give good lovin',
#  'hungry gay guys feeling hungry 4 call 08718730555 10p min stop texts call 08712460324 10p min',
#  'makes happy',
#  'oh lk tt den take e one tt ends cine lor dun wan yogasana oso',
#  'good hear',
#  'ur chance win å 250 cash every wk txt play 83370 s c s www music trivia net custcare 08715705022 1x150p wk',
#  'mum say wan go go shun bian watch da glass exhibition',
#  'hey you still gym',
#  'nimbomsons yep phone knows one obviously cos thats real word',
#  'pain urination thing else',
#  'oh shut omg yesterday dream 2 kids boys pissed kids boys even told mark dream changing diapers cause m getting owed face',
#  'even brother like speak treat like aids patent',
#  'beautiful truth gravity read carefully our heart feels light someone feels heavy someone leaves good night',
#  'feel always happy slowly becomes habit amp finally becomes part life follow happy morning amp happy day',
#  'wont get concentration dear know mind everything',
#  'let ur heart ur compass ur mind ur map ur soul ur guide you never loose world gnun sent via way2sms com',
#  'forwarded 448712404000 please call 08712404000 immediately urgent message waiting',
#  'ya came ago',
#  'spook mob halloween collection logo pic message plus free eerie tone txt card spook 8007 zed 08701417012150p per logo pic',
#  'okay thought expert',
#  'get 3 lions england tone reply lionm 4 mono lionp 4 poly 4 go 2 www ringtones co uk original n best tones 3gbp network operator rates apply',
#  'way m going back',
#  'gain rights wife dont demand it i trying husband too lets see',
#  'dont send plus s mode',
#  'yeah imagine would really gentle unlike docs treat patients like turkeys',
#  'tone club subs expired 2 re sub reply monoc 4 monos polyc 4 polys 1 weekly 150p per week txt stop 2 stop msg free stream 0871212025016',
#  'ugh hopefully asus ppl dont randomly reformat',
#  'gsoh good spam ladies you could b male gigolo 2 join uk s fastest growing mens club reply oncall mjzgroup 08714342399 2stop reply stop msg å 1 50rcvd',
#  'awesome think get 8th usf time tonight',
#  'goodmorning today late lt decimal gt min',
#  'yar say got error',
#  'ur lecture',
#  'love you 2 little pocy bell sorry love you',
#  'you got persons story',
#  'yup ok thanx',
#  'yeah s thought lem know anything s goin later',
#  'bank granite issues strong buy explosive pick members 300 nasdaq symbol cdgt 5 00 per',
#  'also s piece',
#  'know you mean king havin credit m goin2bed night night sweet only1more sleep',
#  'dare stupid wont tell anything hear wont talk',
#  'turns stereo love mi phone unknown album',
#  'dont use hook',
#  'die e toot fringe',
#  'hmm ok ll stay like hour cos eye really sore',
#  'tried contact reply offer video phone 750 anytime network mins half price line rental camcorder reply call 08000930705',
#  'pansy ve living jungle two years driving worried',
#  'kay since already',
#  'oh god happy see message 3 days',
#  'sure neighbors didnt pick',
#  'pete phone still jenny college leanne what',
#  'got called tool',
#  'happen',
#  'right meanwhile s project twins comin',
#  'awesome text re restocked',
#  'you r beautiful girl ive ever seen you r baby come c common room',
#  'chill another 6hrs could sleep pain surgical emergency see unfolds okay',
#  'oh right ok ll make sure loads work day got really nasty cough today dry n shot really help',
#  'you meet ur dream partner soon ur career 2 flyng start 2 find free txt horo followed ur star sign e g horo aries',
#  'pls call da happen',
#  'yeah hopefully tyler ca n t could maybe ask around bit',
#  'tried contact reply offer 750 mins 150 textand new video phone call 08002988890 reply free delivery tomorrow',
#  'network operator service free c s visit 80488 biz',
#  'laughing out loud could starve lose pound end day',
#  'hi mobile lt gt added contact list www fullonsms com great place send free sms people visit fullonsms com',
#  'its ur luck love someone ur fortune love one loves you',
#  ...]

# %%
Y_test.shape
# Out:
# (1034,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
pipeline_RF=Pipeline(steps=[('tv',TfidfVectorizer()),('RF',RandomForestClassifier(n_estimators=100))])
pipeline_RF.fit(X_train_text,Y_train)
acc=pipeline_RF.score(X_test_text,Y_test)
y_pred=pipeline_RF.predict(X_test_text)
cv=cross_val_score(pipeline_RF,X_train_text ,Y_train,scoring='accuracy',cv=5)
precision=precision_score(Y_test,y_pred,average='weighted')
f1=f1_score(Y_test,y_pred,average='weighted')
print(f'F1 score:{f1*100:.2f}')
print(f'precision:{precision*100:.2f}')
print(f'cv:{cv.mean():.2f}')
print(f'Accuracy:{acc*100:.2f}')
# Out:
# F1 score:97.17
# precision:97.37
# cv:0.97
# Accuracy:97.29

# %%
Y_pred=pipeline_RF.predict(['Boltblue tones for 150p Reply POLY# or MONO# eg POLY3 1. Cha Cha Slide 2. Yeah 3. Slow Jamz 6. Toxic 8. Come With Me or STOP 4 more tones txt MORE	'])
Y_pred
# Out:
# array([0], dtype=int64)

# %%
import pickle
with open ('model_1.pkl', 'wb') as f:
    pickle.dump(pipeline_RF , f)
